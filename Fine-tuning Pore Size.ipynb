# %%
import os
from google import genai
from google.genai import types
client = genai.Client(api_key="AIzaSyBPjWqgAnvWasCWuCpIM7mdo0Umuyzz_J8")

with open('materials.json', 'r', encoding='utf-8') as f:
    data_list = json.load(f)

for item in data_list:
    MOFsName = item.get("Materials Name")
    metal = item.get("Metal Nodes")
    ligands = item.get("Ligands")

    # MOFsName = "CopzNi"
    # metal = [
    #             "Co2+",
    #             "Ni2+"
    #         ]
    # ligands = [
    #             "pyrazine",
    #             "tetracyanonickelate"
    #         ]
        
    response = client.models.generate_content(
    model="gemini-2.5-flash-preview-05-20",
    config=types.GenerateContentConfig(
    system_instruction="""
Objective
To precisely fine-tune (rather than drastically alter) the pore aperture of Metal-Organic Frameworks (MOFs) for efficient molecular size sieving applications. This fine-tuning can involve either a slight increase or decrease in pore dimensions.

Task
Given a MOF's current metal node and organic ligand, propose 5-6 distinct and well-reasoned strategies to achieve subtle pore size adjustments. These strategies should consider:

Subtle addition or removal of functional groups on the organic ligand.
Feasible metal node substitution involving metals with subtly different coordination preferences or electronic properties.
Instructions & Guiding Questions
Current MOF Composition:

Please specify the current central metal ion(s) (e.g.,Ni(II), Zn(II), Cu(II), Zr(IV), Fe(III)) and the specific organic ligand(s) (e.g., terephthalate, trimesate, H$_{2}$BDC) that form the MOF you are considering.
Proposed Strategies for Fine-Tuning Pore Size:

For each of your proposed strategies (5-6 distinct suggestions), clearly describe the specific modification. You can propose:
Strategy A: Ligand Functionalization (Subtle Addition/Removal)

What small functional group(s) would you incorporate (e.g., -NH$_{2}$, -F, -Cl, -OH, -CH$_{3}$) or remove (e.g., replace a small -NH$_{2}$ with -H)? Avoid highly bulky groups unless positioned strategically for minimal impact.
Where on the ligand structure would you place/remove these groups to cause a slight steric hindrance or alter local interactions without major structural rearrangements (e.g., specific positions on an aromatic ring that project subtly into the pore)?
How would the minor steric bulk or electronic/polar interactions of these modified groups gently narrow or widen the pore aperture, or subtly change the effective pore size?
Strategy B: Metal Node Substitution (Feasible Subtle Changes)

What alternative metal ion(s) could be substituted for the current metal node? Emphasize isovalent or near-isovalent substitution (e.g., substituting Zn(II) with Co(II) or Mg(II) in an isoreticular fashion).
How would the chosen alternative metal ion, given its:
Ionic Radius: Subtly different ionic radius (e.g., slightly larger or smaller) compared to the original metal, impacting bond lengths and overall unit cell dimensions without changing the topology.
Coordination Mode/Geometry: Potential for slight variations in bond angles or subtle distortions in coordination geometry around the metal center (e.g., a slight tilt or rotation of the polyhedra) even if the primary coordination number remains similar.
Electronic Properties: Subtle differences in d-electron configuration or electronegativity that might influence the rigidity of the metal-ligand bond or the interaction strength with guest molecules, indirectly fine-tuning the effective pore size.
How would these subtle changes in the metal node translate into a fine-tuning of the overall pore aperture? Consider the rigidity of the SBU or the flexibility induced by the metal-ligand bonds.
Predicted Pore Size Change & Underlying Mechanism:

For each proposed strategy (whether ligand functionalization or metal substitution), predict the resulting subtle change in pore aperture (e.g., a change of less than 0.5 Å, or a slight shift in pore shape).
Explain the underlying mechanism by which these specific, subtle modifications (either to the ligand's functional groups or the metal node's properties) lead to the predicted fine-tuning of the pore size.
Output Requirements
Provide clear and concise explanations for each proposed subtle modification.
Justify your choices based on MOF design principles and known structure-property relationships, emphasizing the fine-tuning aspect and feasibility of the proposed metal substitution.
Use accurate scientific terminology (e.g., ionic radius, coordination geometry, d-electron configuration, steric hindrance).
If possible, refer to relevant examples from the literature to support your suggestions for subtle pore modification."""),
    contents=f"MOFs name is {MOFsName}. Metal is {metal}. ligands is {ligands}. Target: Decrease pore size"
    )
    
    # print(response.text)
    print("-" * 20) # 分隔不同 Materials Name 的数据
    print(response.text)
# Out:
# --------------------
# The objective is to achieve precise control over the pore aperture of a given Metal-Organic Framework (MOF), "CopzNi," for efficient molecular size sieving.
#
# **Current MOF Composition:**
#
# *   **Central metal ions:** Co(II), Ni(II)
# *   **Organic ligands:** Pyrazine, Tetracyanonickelate ([Ni(CN)$_4$]$^{2-}$)
#
# **Assumed MOF Structure:**
# Based on the specified components, it is highly probable that "CopzNi" refers to a Prussian Blue Analogue (PBA) type structure incorporating an organic linker, specifically something like **{[Co(pyrazine)][Ni(CN)$_4$]}$_n$**. In this common structural motif:
# *   **Co(II)** typically acts as the primary metal node, often octahedrally coordinated, linking to pyrazine and the nitrogen atoms of the cyanide groups from the [Ni(CN)$_4$]$^{2-}$ units.
# *   **[Ni(CN)$_4$]$^{2-}$** acts as a rigid, square-planar anionic macro-linker, bridging other metal centers (Co(II)) via its cyanide nitrogen atoms.
# ...

# %%
MOFsName = "CopzNi"
metal = [
            "Co2+",
            "Ni2+"
        ]
ligands = [
            "pyrazine",
            "tetracyanonickelate"
        ]
    
response = client.models.generate_content(
model="gemini-2.5-flash-preview-05-20",
config=types.GenerateContentConfig(
system_instruction="""
Objective
To precisely fine-tune (rather than drastically alter) the pore aperture of Metal-Organic Frameworks (MOFs) for efficient molecular size sieving applications. This fine-tuning can involve either a slight increase or decrease in pore dimensions.

Task
Given a MOF's current metal node and organic ligand, propose 5-6 distinct and well-reasoned strategies to achieve subtle pore size adjustments. These strategies should consider:

Subtle addition or removal of functional groups on the organic ligand.
Feasible metal node substitution involving metals with subtly different coordination preferences or electronic properties.
Instructions & Guiding Questions
Current MOF Composition:

Please specify the current central metal ion(s) (e.g.,Ni(II), Zn(II), Cu(II), Zr(IV), Fe(III)) and the specific organic ligand(s) (e.g., terephthalate, trimesate, H$_{2}$BDC) that form the MOF you are considering.
Proposed Strategies for Fine-Tuning Pore Size:

For each of your proposed strategies (5-6 distinct suggestions), clearly describe the specific modification. You can propose:
Strategy A: Ligand Functionalization (Subtle Addition/Removal)

What small functional group(s) would you incorporate (e.g., -NH$_{2}$, -CH$_{3}$) or remove (e.g., replace a small -NH$_{2}$ with -H)? Avoid highly bulky groups unless positioned strategically for minimal impact.
Where on the ligand structure would you place/remove these groups to cause a slight steric hindrance or alter local interactions without major structural rearrangements (e.g., specific positions on an aromatic ring that project subtly into the pore)?
How would the minor steric bulk or electronic/polar interactions of these modified groups gently narrow or widen the pore aperture, or subtly change the effective pore size?
Strategy B: Metal Node Substitution (Feasible Subtle Changes)

What alternative metal ion(s) could be substituted for the current metal node? Emphasize isovalent or near-isovalent substitution (e.g., substituting Zn(II) with Co(II) or Mg(II) in an isoreticular fashion).
How would the chosen alternative metal ion, given its:
Ionic Radius: Subtly different ionic radius (e.g., slightly larger or smaller) compared to the original metal, impacting bond lengths and overall unit cell dimensions without changing the topology.
Coordination Mode/Geometry: Potential for slight variations in bond angles or subtle distortions in coordination geometry around the metal center (e.g., a slight tilt or rotation of the polyhedra) even if the primary coordination number remains similar.
Electronic Properties: Subtle differences in d-electron configuration or electronegativity that might influence the rigidity of the metal-ligand bond or the interaction strength with guest molecules, indirectly fine-tuning the effective pore size.
How would these subtle changes in the metal node translate into a fine-tuning of the overall pore aperture? Consider the rigidity of the SBU or the flexibility induced by the metal-ligand bonds.
Predicted Pore Size Change & Underlying Mechanism:

For each proposed strategy (whether ligand functionalization or metal substitution), predict the resulting subtle change in pore aperture (e.g., a change of less than 0.5 Å, or a slight shift in pore shape).
Explain the underlying mechanism by which these specific, subtle modifications (either to the ligand's functional groups or the metal node's properties) lead to the predicted fine-tuning of the pore size.
Output Requirements
Provide clear and concise explanations for each proposed subtle modification.
Justify your choices based on MOF design principles and known structure-property relationships, emphasizing the fine-tuning aspect and feasibility of the proposed metal substitution.
Use accurate scientific terminology (e.g., ionic radius, coordination geometry, d-electron configuration, steric hindrance).
If possible, refer to relevant examples from the literature to support your suggestions for subtle pore modification."""),
contents=f"MOFs name is {MOFsName}. Metal is {metal}. ligands is {ligands}. Target: Decrease pore size"
)

# print(response.text)
print("-" * 20) # 分隔不同 Materials Name 的数据
print(response.text)
# Out:
# --------------------
# The objective is to subtly decrease the pore aperture of a MOF with Co(II) and Ni(II) metal nodes, and pyrazine (pz) and tetracyanonickelate ([Ni(CN)$_4$]$^{2-}$) ligands. We assume a common structural motif where Co(II) acts as an octahedral nodal metal, coordinated by pyrazine and [Ni(CN)$_4$]$^{2-}$ units, forming a 3D network with accessible pores.
#
# Here are 5 distinct strategies for fine-tuning the pore aperture, focusing on subtle decreases:
#
# ---
#
# **1. Ligand Functionalization: Methylation of Pyrazine**
#
# *   **Specific Modification:** Replace the current pyrazine (C$_4$H$_4$N$_2$) ligand with **2-methylpyrazine** (C$_4$H$_3$(CH$_3$)N$_2$) or **2,5-dimethylpyrazine** (C$_4$H$_2$(CH$_3$)$_2$N$_2$).
# *   **Where on the Ligand:** The methyl group(s) are attached to the carbon atoms of the pyrazine ring, which project into the pore channel.
# *   **Predicted Pore Size Change & Underlying Mechanism:**
# ...
